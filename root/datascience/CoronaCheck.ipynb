# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn

# %%
#read the patients dataset
patient = pd.read_csv("coronavirusdataset/patient.csv")
patient.head(6)
# patient[patient.isnull()]
# Out:
#    id     sex  birth_year country               region group  \
# 0   1  female      1984.0   China  filtered at airport   NaN
# 1   2    male      1964.0   Korea  filtered at airport   NaN
# 2   3    male      1966.0   Korea         capital area   NaN
# 3   4    male      1964.0   Korea         capital area   NaN
# 4   5    male      1987.0   Korea         capital area   NaN
# 5   6    male      1964.0   Korea         capital area   NaN
#
#        infection_reason  infection_order  infected_by  contact_number  \
# 0        visit to Wuhan              1.0          NaN            45.0
# 1        visit to Wuhan              1.0          NaN            75.0
# 2        visit to Wuhan              1.0          NaN            16.0
# 3        visit to Wuhan              1.0          NaN            95.0
# 4        visit to Wuhan              1.0          NaN            31.0
# 5  contact with patient              2.0          3.0            17.0
#
# ...

# %%
#read the time dataset
time = pd.read_csv("coronavirusdataset/time.csv")
time.head(6)
# time[time.isnull()]
# Out:
#          date  acc_test  acc_negative  acc_confirmed  acc_released  \
# 0  2020-01-20         1             0              1             0
# 1  2020-01-21         1             0              1             0
# 2  2020-01-22         4             3              1             0
# 3  2020-01-23        22            21              1             0
# 4  2020-01-24        27            25              2             0
# 5  2020-01-25        27            25              2             0
#
#    acc_deceased  new_test  new_negative  new_confirmed  new_released  \
# 0             0         1             0              1             0
# 1             0         0             0              0             0
# 2             0         3             3              0             0
# 3             0        18            18              0             0
# 4             0         5             4              1             0
# 5             0         0             0              0             0
#
# ...

# %%
#read the routes dataset
routes = pd.read_csv("coronavirusdataset/route.csv")
routes.head(6)
# routes[routes.isnull()]
# Out:
#    id        date     province        city              visit   latitude  \
# 0   1  2020-01-19      Incheon     Jung-gu            airport  37.460459
# 1   1  2020-01-20      Incheon      Seo-gu  hospital_isolated  37.478832
# 2   2  2020-01-22  Gyeonggi-do    Gimpo-si            airport  37.562143
# 3   2  2020-01-23        Seoul     Jung-gu  hospital_isolated  37.567454
# 4   3  2020-01-20      Incheon     Jung-gu            airport  37.460459
# 5   3  2020-01-22        Seoul  Gangnam-gu             clinic  37.524978
#
#     longitude
# 0  126.440680
# 1  126.668558
# 2  126.801884
# 3  127.005627
# 4  126.440680
# 5  127.027718

# %%
patient.describe()
# Out:
#                 id   birth_year  infection_order  infected_by  contact_number
# count  5328.000000   370.000000        35.000000    70.000000       47.000000
# mean   2664.500000  1973.589189         2.285714   379.000000       72.978723
# std    1538.205448    17.560546         1.405272   540.247528      188.155288
# min       1.000000  1932.000000         1.000000     3.000000        0.000000
# 25%    1332.750000  1960.000000         1.000000    29.250000        2.500000
# 50%    2664.500000  1974.000000         2.000000   126.000000       16.000000
# 75%    3996.250000  1987.750000         3.000000   563.250000       46.000000
# max    5328.000000  2018.000000         6.000000  2621.000000     1160.000000

# %%
group_Patient = patient.groupby(["region" , "sex"]).sum()
group_Patient
patient.pivot_table(['infection_reason' , 'birth_year'], index='birth_year', aggfunc='sum')
# Out:
#                                     infection_reason
# birth_year
# 1932.0                                             0
# 1934.0                                             0
# 1935.0                          contact with patient
# 1936.0                          contact with patient
# 1937.0                                             0
# 1940.0                                             0
# 1942.0                                             0
# 1943.0                                             0
# 1947.0                          contact with patient
# 1949.0                                             0
# 1950.0                                             0
# 1952.0                          contact with patient
# 1963.0                                             0
# 1967.0                                             0
# 1969.0                                             0
# 1972.0                                             0
# ...

# %%
group_Patient.boxplot()
